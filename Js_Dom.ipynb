# %% [markdown]
# <a href="https://colab.research.google.com/github/Amankhalsa/js_DOM/blob/main/Js_Dom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Java Script DOM

# %%
#	getElementsByTagName
#	example 
#	document.getElementsByTagName("li")
	
#	getElementsByClassName
#	example
#	document.getElementsByClassName("red")
	
#	getElementById
#	example:
#	document.getElementById("first") 
#	<p id=​"first">​Jobs to do today​</p>​
	
#	querySelector
#	example:
#	document.querySelector("li")
	
#	querySelectorAll
#	example
#	document.querySelectorAll("li")
#	document.querySelectorAll("li,h1")
	
#	getAttribute
#	document.querySelector("li").getAttribute("random")
	23
#	setAttribute
#	document.querySelector("li").setAttribute("random",100)
#	output :"100"
	
#	##Changing Styles
#	style.{property} //ok
#	document.querySelector("h1").style.background="blue"
#	document.querySelector("h1").style.color="red" 
#	className //best
#	var h1= document.querySelector('h1')
#	then run :
#	h1.className="sec"
#	output: "sec"
	
#	#classList.add
#	example
#	document.querySelector("li").classList.add("done")
#	Multiple rupe can define 1
#	document.querySelector("li").classList.add("done")
#	Multiple rupe can define 2
#	document.querySelector("li").classList.add("sec")
#	Multiple rupe can define 3
#	document.querySelector("li").classList.add("red_c")
	
#	#classList.remove:
#	for remove styleing:
#	document.querySelector("li").classList.remove("red_c")
	
#	#classList.toggle
#	my_style.classList.toggle("done")
#	again and again remove and add
#	my_style.classList.toggle("done")
	
#	#Bonus Command
	
#	#innerHTML
#	example:
#	document.querySelector("h1").innerText="this is a nes list"
#	as well as  can use this
#	document.querySelector("h1").innerHTML="to do list 1"
#	to do list 1
	
#	#parentElement
#	example 
#	document.querySelectorAll("li")[3].parentElement;
#	<ul> </ul> is li parent 
#	two time parent will be show body :
#	document.querySelectorAll("li")[3].parentElement.parentElement;
#	body
	
	
#	example 2 for list index wise selection 
#	document.querySelectorAll("li")[1]
#	document.querySelectorAll("li")[3]
#	#children
#	document.querySelectorAll("li")[3].parentElement.children;
	
#	##It is important to CACHE selectors in variables

# %% [markdown]
# ```
# # This is formatted as code
# <!DOCTYPE html>
# <html>
# <head>
# 	<title>Javafile with DOM</title>
# 	<link rel="stylesheet" type="text/css" href="style.css">
# 	<style type="text/css">
#
# .done {text-decoration: line-through; font-size: 2em; } /*	#first{color:rgb(6, 117, 24); }*/ .sec{color:blue; } li{color: red; } P{color: orange; font-size: 2em; } .red_c{color: red; background: yellow; } </style>
#
# </head>
# <body>
# 	<h1 class="first">To do list</h1>
# 	<p id="first">Jobs to do today</p>
# 	<p> Lorem ipsum dolor sit amet, consectetur adipisicing elit,sed do eiusmod</p><p>
# 	tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam,</p>
# 	<p class="sec">This is class text</p>
# 	<ul>
# 		<li class="bold red" random="23">Wake up <p> hi </p></li>
# 		<li>brush teech</li>
#
# 		<li>take shower</li>
# 		<li>go to work</li>
# 		<li>play footbal</li>
#
# 	</ul>
# 	<script type="text/javascript">
#
# 	</script>
# </body>
# </html>
# ```
